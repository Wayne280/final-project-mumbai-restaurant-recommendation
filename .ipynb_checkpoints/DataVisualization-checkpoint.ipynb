# %%
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# # Part 1: Showing the Dataset

# %%
df = pd.read_csv('zomato_res.csv')
df
# Out:
#        Additional_outlet_count  Call Cost_for_two  \
# 0      1 more outlet in Mumbai  True       ₹1,500
# 1      1 more outlet in Mumbai  True         ₹800
# 2                          NaN  True       ₹2,500
# 3                          NaN  True       ₹1,800
# 4     2 more outlets in Mumbai  True         ₹450
# ...                        ...   ...          ...
# 7280                       NaN  True         ₹600
# 7281                       NaN  True         ₹550
# 7282                       NaN  True         ₹350
# 7283                       NaN  True       ₹2,000
# 7284                       NaN  True         ₹600
#
#                                                Cuisines  \
# 0           Finger Food, Continental, European, Italian
# 1                                                 Pizza
# 2                                               Seafood
# 3                              Finger Food, Continental
# 4         North Indian, Street Food, Fast Food, Chinese
# ...

# %% [markdown]
# # Part 2: Introduction

# %% [markdown]
# __Column Legends:__
# - __Additional_outlet_count__: The amount of additional outlet other than the main, if there is/are
# - __Call__: the condition if the restaurant has a phone number to be contacted or not
# - __Cost_for_two__: the average cost estimation for two people
# - __Cuisines__: the type of Cuisines that is served by the restaurant
# - __Delivery_Time_min_orders__: the duration of delivery time per order
# - __Features__: the features that is/are provided by the restaurant
# - __Home_Delivery__: the condition whether the restaurant could provide home delivery service or not
# - __Operational_hours__: The operating hours and days of the restaurant
# - __Rating_votes__: The average rating received by the restaurant
# - __Restaurant_Name__: The name of the restaurant
# - __Restaurant_Type__: The classification of the restaurant in the term of "way of eating"
# - __View_Menu__: The condition if the restaurant provides the menu or not

# %%
# Checking the Null Value
dg = df.copy()
dg.isnull().sum()
# Out:
# Additional_outlet_count    6285
# Call                          0
# Cost_for_two                  0
# Cuisines                      1
# Delivery_Time_min_order    4771
# Features                   5695
# Home_Delivery                 0
# Operational_hours            12
# Rating_votes                  0
# Restaurant_Location          19
# Restaurant_Name               0
# Restaurant_Type             656
# View_Menu                     0
# dtype: int64

# %%
# Removing the Null Value of Cuisines and Features --> Because these two will be our main indicator
dg = df.dropna(subset=['Cuisines', 'Features', 'Restaurant_Type'])
dg.isnull().sum()
# Out:
# Additional_outlet_count    1076
# Call                          0
# Cost_for_two                  0
# Cuisines                      0
# Delivery_Time_min_order     549
# Features                      0
# Home_Delivery                 0
# Operational_hours             0
# Rating_votes                  0
# Restaurant_Location           0
# Restaurant_Name               0
# Restaurant_Type               0
# View_Menu                     0
# dtype: int64

# %%
##### Amount of Row and Column #####
print(f'rows = {df.shape[0]} | columns = {df.shape[1]}')
# Out:
# rows = 7285 | columns = 13

# %% [markdown]
# # Part 3: Data Analysis

# %% [markdown]
# __A. Top 20 Restaurant with Most Outlet__

# %%
sb.set_context('poster')
plt.figure(figsize=(20,15))
books = df['Restaurant_Name'].value_counts()[:20]
sb.barplot(x = books, y = books.index, palette='GnBu_d')
plt.title("Most Frequent Restaurant")
plt.xlabel("Number of occurances")
plt.ylabel("Restaurant Name")
plt.show()

# %% [markdown]
# __B. Price (for Two People) Distribution__

# %%
#### Data Cleaning for 'price for two people' ####


#dg['Cost_for_two'] = dg['Cost_for_two'].str.replace('₹', '') #--> Removing Rupee Symbol
#dg['Cost_for_two'] = dg['Cost_for_two'].str.replace(',', '') #--> Removing koma
#dg['Cost_for_two'] = dg['Cost_for_two'].astype('int64') #--> changing data type from object into int64
dg.dtypes
# Out:
# Additional_outlet_count    object
# Call                         bool
# Cost_for_two                int64
# Cuisines                   object
# Delivery_Time_min_order    object
# Features                   object
# Home_Delivery                bool
# Operational_hours          object
# Rating_votes               object
# Restaurant_Location        object
# Restaurant_Name            object
# Restaurant_Type            object
# View_Menu                    bool
# dtype: object

# %%
plt.figure(figsize=(10,10))
sb.distplot(dg['Cost_for_two'], bins=20)
plt.title("Mumbai Restaurant Price Distribution (for Two People)", fontsize=20)
plt.show()

# %% [markdown]
# __C. Top 20 Restaurant with Highest Meal Cost__

# %%
Classy = dg['Cost_for_two'] > 6000
Regular = dg['Cost_for_two'] <= 6000
dg[Classy].count()
# Out:
# Additional_outlet_count    0
# Call                       3
# Cost_for_two               3
# Cuisines                   3
# Delivery_Time_min_order    0
# Features                   3
# Home_Delivery              3
# Operational_hours          3
# Rating_votes               3
# Restaurant_Location        3
# Restaurant_Name            3
# Restaurant_Type            3
# View_Menu                  3
# dtype: int64

# %%
most_rated = dg.sort_values('Cost_for_two', ascending = False).head(14).set_index('Restaurant_Name').sort_values(by=['Cost_for_two'], ascending=True)

plt.figure(figsize=(15,10))
plt.barh(most_rated.index, most_rated['Cost_for_two'], linewidth=10)
plt.title('Top 20 Restaurant with Highest Meal Cost')
plt.show()

# %% [markdown]
# __D. Top 20 Restaurant Cuisines Frequency in Mumbai__

# %%
from collections import Counter

# %%
#### Converting Every Cuisine Row into List ####
a = []
for c in dg.Cuisines:
    a.append(c.split(","))

# %%
#### Move all the data to single list ####
cuis = []
for i in a:
    for b in i:
        cuis.append(b)

# %%
### using strip, to remove unneccessary space before or after coma ####
cuisines = []
for i in cuis :
    cuisines.append(i.strip())

# %%
### Reset Index to make things tidy and anticipate unexpected things
dg_cuisines = pd.DataFrame.from_dict(Counter(cuisines),orient='index').reset_index()

# %%
### Sort the data 
dgg = dg_cuisines.sort_values(0)

# %%
most_rated = dgg.sort_values(0, ascending = False).head(14).set_index('index').sort_values(by=[0], ascending=True)
plt.figure(figsize=(15,10))
plt.barh(most_rated.index, most_rated[0], linewidth=10)
plt.title('Top 20 Restaurant Cuisines Frequency in Mumbai')
plt.show()

# %% [markdown]
# __E. Top 20 Restaurant Features Frequency in Mumbai__

# %%
#### Converting Every Features Row into List ####
aa = []
for cc in dg.Features:
    aa.append(cc.split(","))

# %%
#### Move all the data to single list ####
feat = []
for i in aa:
    for bb in i:
        feat.append(bb)

# %%
### using strip, to remove unneccessary space before or after coma ####
features = []
for i in feat :
    features.append(i.strip())

# %%
### Reset Index to make things tidy and anticipate unexpected things
dg_features = pd.DataFrame.from_dict(Counter(features),orient='index').reset_index()

# %%
### Sort the data 
dgh = dg_features.sort_values(0)

# %%
most_rated2 = dgh.sort_values(0, ascending = False).head(14).set_index('index').sort_values(by=[0], ascending=True)
plt.figure(figsize=(15,10))
plt.barh(most_rated2.index, most_rated2[0], linewidth=10)
plt.title('Top 20 Restaurant Features Frequency in Mumbai')
plt.show()

# %% [markdown]
# __F. Top 20 Restaurant Type Frequency in Mumbai__

# %%
#### Converting Every Type Row into List ####
aaa = []
for ccc in dg.Restaurant_Type:
    aaa.append(ccc.split(","))

# %%
#### Move all the data to single list ####
ty = []
for i in aaa:
    for bbb in i:
        ty.append(bbb)

# %%
### using strip, to remove unneccessary space before or after coma ####
typee = []
for i in ty :
    typee.append(i.strip())

# %%
### Reset Index to make things tidy and anticipate unexpected things
dg_typee = pd.DataFrame.from_dict(Counter(typee),orient='index').reset_index()

# %%
### Sort the data 
dgi = dg_typee.sort_values(0)

# %%
most_rated3 = dgi.sort_values(0, ascending = False).head(14).set_index('index').sort_values(by=[0], ascending=True)
plt.figure(figsize=(15,10))
plt.barh(most_rated3.index, most_rated3[0], linewidth=10)
plt.title('Top 20 Restaurant Type Frequency in Mumbai')
plt.show()
